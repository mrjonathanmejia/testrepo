# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jonathan**
#
# Future Data Scientist

# %% [markdown]
# *I am interested in data science because I am fascinated by the power of coding and I believe I can create many great things with the power of data.*

# %% [markdown]
# ### In code cell 5, I wrote a code chunk that displays the date and time

# %%
import datetime

x = datetime.datetime.now()
print(x)
# Out:
# 2022-09-19 01:54:24.375139

# %% [markdown]
# Top 3 anime
#   * Naruto
#   * Demon Slayer
#   * Attack On Titan
#
# Anime Ranks
#   1. Naruto
#   2. Demon Slayer
#   3. Attack On Titan
#
# [Demon Slayer Compilation](https://www.youtube.com/watch?v=FKRHsMGP3vQ)
